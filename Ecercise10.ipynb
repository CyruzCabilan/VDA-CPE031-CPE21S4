# %% [markdown]
# <a href="https://colab.research.google.com/github/CyruzCabilan/VDA-CPE031-CPE21S4/blob/main/Ecercise10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.array([60,90,70,85,80,65,75,60,75,70])
y = np.array([70,95,70,75,90,75,75,60,80,65])

slope, intercept = np.polyfit(x, y, 1)

y_pred = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.xlabel('Proficiency Exam Score')
plt.ylabel('Cours Grade')
plt.title('Student Performance')
plt.show()
